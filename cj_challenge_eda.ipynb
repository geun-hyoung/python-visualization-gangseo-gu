# %% [markdown]
# <a href="https://colab.research.google.com/github/geun-hyoung/DataAnalysis_Gangseo-gu/blob/main/cj_challenge_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setting

# %% [markdown]
# ## install Package

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
pip install -U googlemaps
# Out:
# Requirement already satisfied: googlemaps in /usr/local/lib/python3.10/dist-packages (4.10.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from googlemaps) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Library

# %%
import pandas as pd
import folium
from folium import plugins
from folium.features import DivIcon

import json
import seaborn as sns

import matplotlib.pyplot as plt


import googlemaps
import folium

# 해당 키는 : 구글 본인계정에서 발급 :
my_key = "AIzaSyCvl_s-0JGHFSBbwh0LS6RiKqX--HU69P8"
maps = googlemaps.Client(key=my_key)

# 브라우저에서 바로 그려지도록
# %matplotlib inline

# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# Colab 의 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# ## Load Data

# %%
order_table = pd.read_csv('/content/drive/MyDrive/cj_challenge/orders_table.csv', encoding = 'cp949')
terminal_table = pd.read_csv('/content/drive/MyDrive/cj_challenge/terminals.csv', encoding = 'cp949')
veh_table = pd.read_csv('/content/drive/MyDrive/cj_challenge/veh_table.csv')
od_table = pd.read_csv('/content/drive/MyDrive/cj_challenge/od_matrix.csv')

# %%
order_table
# Out:
#                       주문ID     하차지_위도      하차지_경도    착지ID        CBM  \
# 0      20230501B464859_001  36.448483  127.409240     D_1  27.893621
# 1      20230501B464914_001  36.448483  127.409240     D_1  42.669815
# 2      20230501B464917_001  36.448483  127.409240     D_1  27.343155
# 3      20230501B464927_001  36.448483  127.409240     D_1  19.722170
# 4      20230501B464944_001  36.448483  127.409240     D_1  28.031678
# ...                    ...        ...         ...     ...        ...
# 15612            PND000304  36.639999  127.463585  D_2902  19.244336
# 15613            PND000380  37.342094  127.859909  D_2917  23.038265
# 15614            PND000469  37.332897  129.070282  D_2965  18.741028
# 15615            PND000498  37.654900  127.236572  D_1567  28.702799
# 15616            PND000515  37.342094  127.859909  D_2917  13.520532
#
#       하차가능시간_시작 하차가능시간_종료  하차작업시간(분)  터미널ID        date  Group
# 0         18:00      2:00         60  O_179  2023-05-01      0
# 1         18:00      2:00         60  O_673  2023-05-01      1
# 2         18:00      2:00         60  O_673  2023-05-01      2
# 3         18:00      2:00         60  O_179  2023-05-01      3
# 4         18:00      2:00         60  O_673  2023-05-01      0
# ...         ...       ...        ...    ...         ...    ...
# 15612     10:00     17:00         60  O_580  2023-05-01      1
# 15613     18:00      2:00         60  O_349  2023-05-05      1
# 15614     00:00      6:00         60  O_553  2023-05-03      0
# 15615     00:00      6:00         60  O_349  2023-05-04      2
# 15616     18:00      2:00         60  O_349  2023-05-03      1
#
# [15617 rows x 11 columns]

# %%
terminal_table['상차지권역'] = terminal_table['상차지권역'].str.replace('권', ' ')
terminal_table.sort_values('ID')
terminal_table
# Out:
#        ID  Origin_Lat  Origin_Lon 상차지권역
# 0     O_9   35.293174  129.011855   부산
# 1    O_11   37.330883  126.937500   군포
# 2    O_34   36.502321  128.176755   김천
# 3    O_45   35.670293  127.930815   진주
# 4    O_50   35.944794  128.925342   포항
# 5    O_62   37.460667  127.040010   서울
# 6    O_70   35.759545  128.396123   창녕
# 7   O_123   35.594343  126.864643   정읍
# 8   O_144   36.383506  127.424400   대전
# 9   O_174   37.497903  127.232946   성남
# 10  O_179   36.733748  127.168490   청주
# 11  O_243   37.716278  126.687926   파주
# 12  O_284   34.984867  127.492226   광양
# 13  O_292   35.282017  126.986526   순창
# 14  O_323   35.918480  128.283508   구미
# 15  O_326   37.231251  127.110260   용인
# 16  O_349   36.418171  126.947693   공주
# 17  O_352   35.865551  127.088409   군산
# 18  O_376   35.845699  128.592590   대구
# 19  O_430   35.826427  129.255753   안동
# 20  O_448   36.670982  126.774322   당진
# 21  O_466   35.151020  126.789886   광주
# 22  O_553   37.923759  128.796875   강릉
# 23  O_578   37.059460  128.073242   제천
# 24  O_580   37.409409  127.952270   원주
# 25  O_591   35.508259  129.297012   울산
# 26  O_603   37.156906  127.054390   화성
# 27  O_629   36.942848  127.529312   음성
# 28  O_673   37.563065  126.666252   인천
# 29  O_685   34.694008  126.901817   목포
# 30  O_711   37.882008  127.210083   포천
# 31  O_756   37.746819  127.960381   춘천
# 32  O_770   34.998322  128.299881   거제

# %%
veh_table
# Out:
#         VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 0        VEH_2    5000        00:00:00      23:59:59          27         O_9
# 1        VEH_3    5000        00:00:00      23:59:59          27         O_9
# 2        VEH_4    5000        00:00:00      23:59:59          27         O_9
# 3        VEH_5    5000        00:00:00      23:59:59          27         O_9
# 4        VEH_6    5000        00:00:00      23:59:59          27         O_9
# ...        ...     ...             ...           ...         ...         ...
# 1120  VEH_1122   25000        00:00:00      23:59:59          55       O_770
# 1121  VEH_1123   25000        00:00:00      23:59:59          55       O_770
# 1122  VEH_1124   25000        00:00:00      23:59:59          55       O_770
# 1123  VEH_1125   25000        00:00:00      23:59:59          55       O_770
# 1124  VEH_1126   25000        00:00:00      23:59:59          55       O_770
#
#       FixedCost  VariableCost
# 0            80           0.8
# 1            80           0.8
# 2            80           0.8
# 3            80           0.8
# 4            80           0.8
# ...         ...           ...
# 1120        250           1.8
# 1121        250           1.8
# 1122        250           1.8
# 1123        250           1.8
# 1124        250           1.8
#
# [1125 rows x 8 columns]

# %%
od_table
# Out:
#         origin destination  length(meter)   time(min)
# 0         D_69        D_69       0.000000    0.000000
# 1         D_69      D_1916      10.570963    6.912456
# 2         D_69       D_562      13.150193    8.981368
# 3         D_69        D_12      18.617520   14.798563
# 4         D_69      D_1587      27.680115   20.461350
# ...        ...         ...            ...         ...
# 2130439  O_770      D_1322     330.121395  431.255745
# 2130440  O_770      D_1714     336.276097  438.236015
# 2130441  O_770        D_77     342.411007  512.103601
# 2130442  O_770      D_1779     344.145080  506.365793
# 2130443  O_770       D_584     347.051554  507.852638
#
# [2130444 rows x 4 columns]

# %% [markdown]
# #EDA

# %% [markdown]
# ### Order_tabel

# %%
order_table.describe()
# 하차작업시간은 모두 60분으로 통일
# Out:
#              하차지_위도        하차지_경도           CBM  하차작업시간(분)         Group
# count  15617.000000  15617.000000  15617.000000    15617.0  15617.000000
# mean      36.760127    127.453738     23.925663       60.0      1.499520
# std        0.802197      0.693065      9.601934        0.0      1.118041
# min       34.340106    126.250247      5.000000       60.0      0.000000
# 25%       36.252781    127.011814     16.950863       60.0      0.000000
# 50%       37.096394    127.312934     23.838569       60.0      1.000000
# 75%       37.414307    127.624542     30.653607       60.0      2.000000
# max       38.242850    129.486435     45.000000       60.0      3.000000

# %%
print("배송 도착지 종류:", len(list(order_table['착지ID'].unique())))
print("배송 출발지 종류(터미널 갯수):", len(list(order_table['터미널ID'].unique())))
# Out:
# 배송 도착지 종류: 1455
# 배송 출발지 종류(터미널 갯수): 33

# %%
#ot_group = order_table.groupby('Group').count()
# ot_group #그룹 별 주문량
# ot_group_terminal_arrival = order_table.sort_values('주문_ID').groupby(['터미널_ID','착지_ID'])['주문_ID'].count()
# ot_group_terminal_arrival # 시작지점 -> 도착지 주문량 개수 파악
# ot_group_arrival_terminal = order_table.sort_values('주문_ID').groupby(['착지_ID','터미널_ID'])['주문_ID'].count()
# ot_group_arrival_terminal # 도착지 -> 시작지점 주문량 개수 파악
# terminal_ot = order_table[['터미널ID','주문ID']].groupby('터미널ID').count()
# terminal_ot.columns = ['OrderCount']
# terminal_ot ## 터미널 별 주문 개수

# %%
terminal_table['상차지권역']
# Out:
# 0     부산
# 1     군포
# 2     김천
# 3     진주
# 4     포항
# 5     서울
# 6     창녕
# 7     정읍
# 8     대전
# 9     성남
# 10    청주
# 11    파주
# 12    광양
# 13    순창
# 14    구미
# 15    용인
# 16    공주
# 17    군산
# 18    대구
# 19    안동
# 20    당진
# 21    광주
# 22    강릉
# 23    제천
# 24    원주
# 25    울산
# 26    화성
# 27    음성
# 28    인천
# 29    목포
# 30    포천
# 31    춘천
# 32    거제
# Name: 상차지권역, dtype: object

# %%
terminal_ot = order_table[['터미널ID','주문ID']].groupby('터미널ID').count()
terminal_ot.sort_values('터미널ID')
terminal_ot.columns = ['OrderCount']

# terminal_ot['region'] = list(terminal_table['상차지권역'])
# terminal_ot.set_index(keys = ['region'], inplace = True, drop = True)

terminal_ot
# Out:
#        OrderCount
# 터미널ID
# O_11          843
# O_123          56
# O_144        2171
# O_174         184
# O_179         871
# O_243        1002
# O_284          35
# O_292          15
# O_323         345
# O_326        4527
# O_34           40
# O_349         125
# O_352         177
# O_376         335
# O_430          97
# O_448         579
# O_45           48
# O_466          45
# O_50          347
# O_553          17
# O_578          88
# O_580          67
# O_591          95
# O_603         375
# O_62          408
# O_629         237
# O_673        1604
# O_685          39
# O_70           28
# O_711          88
# O_756          12
# O_770          13
# O_9           704

# %%
index = terminal_ot.index
count = terminal_ot['OrderCount']

plt.figure(figsize = (20,8))
plt.bar(index, count)

plt.title('Order of Terminal')
plt.xlabel('Terminal_ID')
plt.ylabel('Orders')

for i, v in enumerate(index):
  plt.text(v, count[v],count[v], horizontalalignment = 'center')

# %% [markdown]
# ##Terminal_Table

# %%
terminal_table['상차지권역'] = terminal_table['상차지권역'].str.replace('권', ' ')

# %%
terminal_table.isnull().sum()
# Out:
# ID            0
# Origin_Lat    0
# Origin_Lon    0
# 상차지권역         0
# dtype: int64

# %%
terminal_table.shape ##33개의 터미널 존재
# Out:
# (33, 4)

# %%
terminal_table.dtypes ##데이터 형식
# Out:
# ID             object
# Origin_Lat    float64
# Origin_Lon    float64
# 상차지권역          object
# dtype: object

# %%
terminal_loc = terminal_table[['ID','Origin_Lat','Origin_Lon','상차지권역']]
terminal_map = folium.Map(location=[terminal_loc.Origin_Lat.mean(), terminal_loc.Origin_Lon.mean()], zoom_start=7, control_scale=True )
for index, location_info in terminal_loc.iterrows():
    folium.Circle([location_info["Origin_Lat"], location_info["Origin_Lon"]], popup = location_info['상차지권역'], radius = 100, fill = 'blue').add_to(terminal_map)
    folium.map.Marker(
    [location_info["Origin_Lat"], location_info["Origin_Lon"]],
    icon=DivIcon(
        icon_size=(150,36),
        icon_anchor=(0,0),
        html="<div style='font-size: 12pt'><b style = 'color : black'>"+location_info['ID'] + '/' + location_info['상차지권역'] +'</b></div>'
        )
    ).add_to(terminal_map)
terminal_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cddb95a97a92de2a52752a6006409ee3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cddb95a97a92de2a52752a6006409ee3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cddb95a97a92de2a52752a6006409ee3 = L.map(
#                 &quot;map_cddb95a97a92de2a52752a6006409ee3&quot;,
#                 {
#                     center: [36.42323584848485, 127.66240887878787],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_cddb95a97a92de2a52752a6006409ee3);
#
#
#
#
#
#             var tile_layer_30a8feac949f899dc5b3b23d45a03361 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cddb95a97a92de2a52752a6006409ee3);
#
#
#             var circle_9d183d4c7c985d57a2bf274219564f21 = L.circle(
#                 [35.293174, 129.011855],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cddb95a97a92de2a52752a6006409ee3);
#
#
#         var popup_1a66009c050d5dfeaeaec3d1915571b3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6a580d7ce3110162c0f8cf78e57816d = $(`&lt;div id=&quot;html_e6a580d7ce3110162c0f8cf78e57816d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산 &lt;/div&gt;`)[0];
#                 popup_1a66009c050d5dfeaeaec3d1915571b3.setContent(html_e6a580d7ce3110162c0f8cf78e57816d);
#
#
#
#         circle_9d183d4c7c985d57a2bf274219564f21.bindPopup(popup_1a66009c050d5dfeaeaec3d1915571b3)
#         ;
#
#
#
#
#             var marker_dfb7b1924c32e2e8e0c8ca15963595c7 = L.marker(
#                 [35.293174, 129.011855],
#                 {}
#             ).addTo(map_cddb95a97a92de2a52752a6006409ee3);
#
#
#             var div_icon_a410b6d2aa919b6deb6d8a91f387718f = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\u0027font-size: 12pt\u0027\u003e\u003cb style = \u0027color : black\u0027\u003eO_9/\ubd80\uc0b0 \u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [150, 36]});
#             marker_dfb7b1924c32e2e8e0c8ca15963595c7.setIcon(div_icon_a410b6d2aa919b6deb6d8a91f387718f);
#
#
#             var circle_93e9fed9d15b8d4e8eb5425696682a9e = L.circle(
#                 [37.330883, 126.9375],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cddb95a97a92de2a52752a6006409ee3);
#
#
#         var popup_994a6c3b481788f4c83e35edc914aef7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47c6ee67d01418451733776cf781a6f7 = $(`&lt;div id=&quot;html_47c6ee67d01418451733776cf781a6f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;군포 &lt;/div&gt;`)[0];
#                 popup_994a6c3b481788f4c83e35edc914aef7.setContent(html_47c6ee67d01418451733776cf781a6f7);
#
#
#
#         circle_93e9fed9d15b8d4e8eb5425696682a9e.bindPopup(popup_994a6c3b481788f4c83e35edc914aef7)
#         ;
#
#
#
#
#             var marker_9d4d246e7a000a82e5c4dc94177674f2 = L.marker(
#                 [37.330883, 126.9375],
#                 {}
#             ).addTo(map_cddb95a97a92de2a52752a6006409ee3);
#
#
#             var div_icon_2c8d5468bc0b8af20d0fc46004038187 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\u0027font-size: 12pt\u0027\u003e\u003cb style = \u0027color : black\u0027\u003eO_11/\uad70\ud3ec \u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [150, 36]});
#             marker_9d4d246e7a000a82e5c4dc94177674f2.setIcon(div_icon_2c8d5468bc0b8af20d0fc46004038187);
#
#
#             var circle_39b782514a5acdd06d463d10685cb1ac = L.circle(
#                 [36.502321, 128.176755],
#                 {&quot;bubblingMo

# %% [markdown]
# ##Veh_Table

# %%
veh_table.isnull().sum()
# Out:
# VehNum             0
# VehTon             0
# BusinessStartTM    0
# BusinessEndTM      0
# MaxCapaCBM         0
# StartCenter        0
# FixedCost          0
# VariableCost       0
# dtype: int64

# %%
veh_table.shape
# Out:
# (1125, 8)

# %%
veh_table.dtypes
# Out:
# VehNum              object
# VehTon               int64
# BusinessStartTM     object
# BusinessEndTM       object
# MaxCapaCBM           int64
# StartCenter         object
# FixedCost            int64
# VariableCost       float64
# dtype: object

# %%
pre_veh_table = pd.DataFrame(veh_table)
pre_veh_table.drop(['VehNum', 'StartCenter'], axis = 'columns', inplace = True)
pre_veh_table
# Out:
#       VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM  FixedCost  \
# 0       5000        00:00:00      23:59:59          27         80
# 1       5000        00:00:00      23:59:59          27         80
# 2       5000        00:00:00      23:59:59          27         80
# 3       5000        00:00:00      23:59:59          27         80
# 4       5000        00:00:00      23:59:59          27         80
# ...      ...             ...           ...         ...        ...
# 1120   25000        00:00:00      23:59:59          55        250
# 1121   25000        00:00:00      23:59:59          55        250
# 1122   25000        00:00:00      23:59:59          55        250
# 1123   25000        00:00:00      23:59:59          55        250
# 1124   25000        00:00:00      23:59:59          55        250
#
#       VariableCost
# 0              0.8
# 1              0.8
# 2              0.8
# 3              0.8
# 4              0.8
# ...            ...
# 1120           1.8
# 1121           1.8
# 1122           1.8
# 1123           1.8
# 1124           1.8
#
# [1125 rows x 6 columns]

# %%
pre_veh_table.groupby('VehTon').count() # ton별 차량 개수
# Out:
#         BusinessStartTM  BusinessEndTM  MaxCapaCBM  FixedCost  VariableCost
# VehTon
# 5000                225            225         225        225           225
# 8000                225            225         225        225           225
# 11000               225            225         225        225           225
# 18000               225            225         225        225           225
# 25000               225            225         225        225           225

# %%
for (k1, k2), group in veh_table.groupby(['StartCenter', 'VehTon']):
    print((k1, k2))
    # 터미널 별 차량 톤에 따른 개수
    display(group.head())
    # vehTon에 따라서 MaxCapaCBM, FixedCost, VariableCost는 같음
# Out:
# ('O_11', 5000)
#    VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 50     52    5000        00:00:00      23:59:59          27        O_11
# 51     53    5000        00:00:00      23:59:59          27        O_11
# 52     54    5000        00:00:00      23:59:59          27        O_11
# 53     55    5000        00:00:00      23:59:59          27        O_11
# 54     56    5000        00:00:00      23:59:59          27        O_11
#
#     FixedCost  VariableCost
# 50         80           0.8
# 51         80           0.8
# 52         80           0.8
# 53         80           0.8
# 54         80           0.8
# ('O_11', 8000)
#    VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 60     62    8000        00:00:00      23:59:59          33        O_11
# 61     63    8000        00:00:00      23:59:59          33        O_11
# 62     64    8000        00:00:00      23:59:59          33        O_11
# 63     65    8000        00:00:00      23:59:59          33        O_11
# 64     66    8000        00:00:00      23:59:59          33        O_11
#
#     FixedCost  VariableCost
# 60        110           1.0
# 61        110           1.0
# 62        110           1.0
# 63        110           1.0
# 64        110           1.0
# ('O_11', 11000)
#    VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 70     72   11000        00:00:00      23:59:59          42        O_11
# 71     73   11000        00:00:00      23:59:59          42        O_11
# 72     74   11000        00:00:00      23:59:59          42        O_11
# 73     75   11000        00:00:00      23:59:59          42        O_11
# 74     76   11000        00:00:00      23:59:59          42        O_11
#
#     FixedCost  VariableCost
# 70        150           1.2
# 71        150           1.2
# 72        150           1.2
# 73        150           1.2
# 74        150           1.2
# ('O_11', 18000)
#    VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 80     82   18000        00:00:00      23:59:59          51        O_11
# 81     83   18000        00:00:00      23:59:59          51        O_11
# 82     84   18000        00:00:00      23:59:59          51        O_11
# 83     85   18000        00:00:00      23:59:59          51        O_11
# 84     86   18000        00:00:00      23:59:59          51        O_11
#
#     FixedCost  VariableCost
# 80        200           1.5
# 81        200           1.5
# 82        200           1.5
# 83        200           1.5
# 84        200           1.5
# ('O_11', 25000)
#    VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 90     92   25000        00:00:00      23:59:59          55        O_11
# 91     93   25000        00:00:00      23:59:59          55        O_11
# 92     94   25000        00:00:00      23:59:59          55        O_11
# 93     95   25000        00:00:00      23:59:59          55        O_11
# 94     96   25000        00:00:00      23:59:59          55        O_11
#
#     FixedCost  VariableCost
# 90        250           1.8
# 91        250           1.8
# 92        250           1.8
# 93        250           1.8
# 94        250           1.8
# ('O_123', 5000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 225    227    5000        00:00:00      23:59:59          27       O_123
# 226    228    5000        00:00:00      23:59:59          27       O_123
# 227    229    5000        00:00:00      23:59:59          27       O_123
# 228    230    5000        00:00:00      23:59:59          27       O_123
# 229    231    5000        00:00:00      23:59:59          27       O_123
#
#      FixedCost  VariableCost
# 225         80           0.8
# 226         80           0.8
# 227         80           0.8
# 228         80           0.8
# 229         80           0.8
# ('O_123', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 230    232    8000        00:00:00      23:59:59          33       O_123
# 231    233    8000        00:00:00      23:59:59          33       O_123
# 232    234    8000        00:00:00      23:59:59          33       O_123
# 233    235    8000        00:00:00      23:59:59          33       O_123
# 234    236    8000        00:00:00      23:59:59          33       O_123
#
#      FixedCost  VariableCost
# 230        110           1.0
# 231        110           1.0
# 232        110           1.0
# 233        110           1.0
# 234        110           1.0
# ('O_123', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 235    237   11000        00:00:00      23:59:59          42       O_123
# 236    238   11000        00:00:00      23:59:59          42       O_123
# 237    239   11000        00:00:00      23:59:59          42       O_123
# 238    240   11000        00:00:00      23:59:59          42       O_123
# 239    241   11000        00:00:00      23:59:59          42       O_123
#
#      FixedCost  VariableCost
# 235        150           1.2
# 236        150           1.2
# 237        150           1.2
# 238        150           1.2
# 239        150           1.2
# ('O_123', 18000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 240    242   18000        00:00:00      23:59:59          51       O_123
# 241    243   18000        00:00:00      23:59:59          51       O_123
# 242    244   18000        00:00:00      23:59:59          51       O_123
# 243    245   18000        00:00:00      23:59:59          51       O_123
# 244    246   18000        00:00:00      23:59:59          51       O_123
#
#      FixedCost  VariableCost
# 240        200           1.5
# 241        200           1.5
# 242        200           1.5
# 243        200           1.5
# 244        200           1.5
# ('O_123', 25000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 245    247   25000        00:00:00      23:59:59          55       O_123
# 246    248   25000        00:00:00      23:59:59          55       O_123
# 247    249   25000        00:00:00      23:59:59          55       O_123
# 248    250   25000        00:00:00      23:59:59          55       O_123
# 249    251   25000        00:00:00      23:59:59          55       O_123
#
#      FixedCost  VariableCost
# 245        250           1.8
# 246        250           1.8
# 247        250           1.8
# 248        250           1.8
# 249        250           1.8
# ('O_144', 5000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 250    252    5000        00:00:00      23:59:59          27       O_144
# 251    253    5000        00:00:00      23:59:59          27       O_144
# 252    254    5000        00:00:00      23:59:59          27       O_144
# 253    255    5000        00:00:00      23:59:59          27       O_144
# 254    256    5000        00:00:00      23:59:59          27       O_144
#
#      FixedCost  VariableCost
# 250         80           0.8
# 251         80           0.8
# 252         80           0.8
# 253         80           0.8
# 254         80           0.8
# ('O_144', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 265    267    8000        00:00:00      23:59:59          33       O_144
# 266    268    8000        00:00:00      23:59:59          33       O_144
# 267    269    8000        00:00:00      23:59:59          33       O_144
# 268    270    8000        00:00:00      23:59:59          33       O_144
# 269    271    8000        00:00:00      23:59:59          33       O_144
#
#      FixedCost  VariableCost
# 265        110           1.0
# 266        110           1.0
# 267        110           1.0
# 268        110           1.0
# 269        110           1.0
# ('O_144', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 280    282   11000        00:00:00      23:59:59          42       O_144
# 281    283   11000        00:00:00      23:59:59          42       O_144
# 282    284   11000        00:00:00      23:59:59          42       O_144
# 283    285   11000        00:00:00      23:59:59          42       O_144
# 284    286   11000        00:00:00      23:59:59          42       O_144
#
#      FixedCost  VariableCost
# 280        150           1.2
# 281        150           1.2
# 282        150           1.2
# 283        150           1.2
# 284        150           1.2
# ('O_144', 18000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 295    297   18000        00:00:00      23:59:59          51       O_144
# 296    298   18000        00:00:00      23:59:59          51       O_144
# 297    299   18000        00:00:00      23:59:59          51       O_144
# 298    300   18000        00:00:00      23:59:59          51       O_144
# 299    301   18000        00:00:00      23:59:59          51       O_144
#
#      FixedCost  VariableCost
# 295        200           1.5
# 296        200           1.5
# 297        200           1.5
# 298        200           1.5
# 299        200           1.5
# ('O_144', 25000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 310    312   25000        00:00:00      23:59:59          55       O_144
# 311    313   25000        00:00:00      23:59:59          55       O_144
# 312    314   25000        00:00:00      23:59:59          55       O_144
# 313    315   25000        00:00:00      23:59:59          55       O_144
# 314    316   25000        00:00:00      23:59:59          55       O_144
#
#      FixedCost  VariableCost
# 310        250           1.8
# 311        250           1.8
# 312        250           1.8
# 313        250           1.8
# 314        250           1.8
# ('O_174', 5000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 325    327    5000        00:00:00      23:59:59          27       O_174
# 326    328    5000        00:00:00      23:59:59          27       O_174
# 327    329    5000        00:00:00      23:59:59          27       O_174
# 328    330    5000        00:00:00      23:59:59          27       O_174
# 329    331    5000        00:00:00      23:59:59          27       O_174
#
#      FixedCost  VariableCost
# 325         80           0.8
# 326         80           0.8
# 327         80           0.8
# 328         80           0.8
# 329         80           0.8
# ('O_174', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 330    332    8000        00:00:00      23:59:59          33       O_174
# 331    333    8000        00:00:00      23:59:59          33       O_174
# 332    334    8000        00:00:00      23:59:59          33       O_174
# 333    335    8000        00:00:00      23:59:59          33       O_174
# 334    336    8000        00:00:00      23:59:59          33       O_174
#
#      FixedCost  VariableCost
# 330        110           1.0
# 331        110           1.0
# 332        110           1.0
# 333        110           1.0
# 334        110           1.0
# ('O_174', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 335    337   11000        00:00:00      23:59:59          42       O_174
# 336    338   11000        00:00:00      23:59:59          42       O_174
# 337    339   11000        00:00:00      23:59:59          42       O_174
# 338    340   11000        00:00:00      23:59:59          42       O_174
# 339    341   11000        00:00:00      23:59:59          42       O_174
#
#      FixedCost  VariableCost
# 335        150           1.2
# 336        150           1.2
# 337        150           1.2
# 338        150           1.2
# 339        150           1.2
# ('O_174', 18000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 340    342   18000        00:00:00      23:59:59          51       O_174
# 341    343   18000        00:00:00      23:59:59          51       O_174
# 342    344   18000        00:00:00      23:59:59          51       O_174
# 343    345   18000        00:00:00      23:59:59          51       O_174
# 344    346   18000        00:00:00      23:59:59          51       O_174
#
#      FixedCost  VariableCost
# 340        200           1.5
# 341        200           1.5
# 342        200           1.5
# 343        200           1.5
# 344        200           1.5
# ('O_174', 25000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 345    347   25000        00:00:00      23:59:59          55       O_174
# 346    348   25000        00:00:00      23:59:59          55       O_174
# 347    349   25000        00:00:00      23:59:59          55       O_174
# 348    350   25000        00:00:00      23:59:59          55       O_174
# 349    351   25000        00:00:00      23:59:59          55       O_174
#
#      FixedCost  VariableCost
# 345        250           1.8
# 346        250           1.8
# 347        250           1.8
# 348        250           1.8
# 349        250           1.8
# ('O_179', 5000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 350    352    5000        00:00:00      23:59:59          27       O_179
# 351    353    5000        00:00:00      23:59:59          27       O_179
# 352    354    5000        00:00:00      23:59:59          27       O_179
# 353    355    5000        00:00:00      23:59:59          27       O_179
# 354    356    5000        00:00:00      23:59:59          27       O_179
#
#      FixedCost  VariableCost
# 350         80           0.8
# 351         80           0.8
# 352         80           0.8
# 353         80           0.8
# 354         80           0.8
# ('O_179', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 360    362    8000        00:00:00      23:59:59          33       O_179
# 361    363    8000        00:00:00      23:59:59          33       O_179
# 362    364    8000        00:00:00      23:59:59          33       O_179
# 363    365    8000        00:00:00      23:59:59          33       O_179
# 364    366    8000        00:00:00      23:59:59          33       O_179
#
#      FixedCost  VariableCost
# 360        110           1.0
# 361        110           1.0
# 362        110           1.0
# 363        110           1.0
# 364        110           1.0
# ('O_179', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 370    372   11000        00:00:00      23:59:59          42       O_179
# 371    373   11000        00:00:00      23:59:59          42       O_179
# 372    374   11000        00:00:00      23:59:59          42       O_179
# 373    375   11000        00:00:00      23:59:59          42       O_179
# 374    376   11000        00:00:00      23:59:59          42       O_179
#
#      FixedCost  VariableCost
# 370        150           1.2
# 371        150           1.2
# 372        150           1.2
# 373        150           1.2
# 374        150           1.2
# ('O_179', 18000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 380    382   18000        00:00:00      23:59:59          51       O_179
# 381    383   18000        00:00:00      23:59:59          51       O_179
# 382    384   18000        00:00:00      23:59:59          51       O_179
# 383    385   18000        00:00:00      23:59:59          51       O_179
# 384    386   18000        00:00:00      23:59:59          51       O_179
#
#      FixedCost  VariableCost
# 380        200           1.5
# 381        200           1.5
# 382        200           1.5
# 383        200           1.5
# 384        200           1.5
# ('O_179', 25000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 390    392   25000        00:00:00      23:59:59          55       O_179
# 391    393   25000        00:00:00      23:59:59          55       O_179
# 392    394   25000        00:00:00      23:59:59          55       O_179
# 393    395   25000        00:00:00      23:59:59          55       O_179
# 394    396   25000        00:00:00      23:59:59          55       O_179
#
#      FixedCost  VariableCost
# 390        250           1.8
# 391        250           1.8
# 392        250           1.8
# 393        250           1.8
# 394        250           1.8
# ('O_243', 5000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 400    402    5000        00:00:00      23:59:59          27       O_243
# 401    403    5000        00:00:00      23:59:59          27       O_243
# 402    404    5000        00:00:00      23:59:59          27       O_243
# 403    405    5000        00:00:00      23:59:59          27       O_243
# 404    406    5000        00:00:00      23:59:59          27       O_243
#
#      FixedCost  VariableCost
# 400         80           0.8
# 401         80           0.8
# 402         80           0.8
# 403         80           0.8
# 404         80           0.8
# ('O_243', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 415    417    8000        00:00:00      23:59:59          33       O_243
# 416    418    8000        00:00:00      23:59:59          33       O_243
# 417    419    8000        00:00:00      23:59:59          33       O_243
# 418    420    8000        00:00:00      23:59:59          33       O_243
# 419    421    8000        00:00:00      23:59:59          33       O_243
#
#      FixedCost  VariableCost
# 415        110           1.0
# 416        110           1.0
# 417        110           1.0
# 418        110           1.0
# 419        110           1.0
# ('O_243', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 430    432   11000        00:00:00      23:59:59          42       O_243
# 431    433   11000        00:00:00      23:59:59          42       O_243
# 432    434   11000        00:00:00      23:59:59          42       O_243
# 433    435   11000        00:00:00      23:59:59          42       O_243
# 434    436   11000        00:00:00      23:59:59          42       O_243
#
#      FixedCost  VariableCost
# 430        150           1.2
# 431        150           1.2
# 432        150           1.2
# 433        150           1.2
# 434        150           1.2
# ('O_243', 18000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 445    447   18000        00:00:00      23:59:59          51       O_243
# 446    448   18000        00:00:00      23:59:59          51       O_243
# 447    449   18000        00:00:00      23:59:59          51       O_243
# 448    450   18000        00:00:00      23:59:59          51       O_243
# 449    451   18000        00:00:00      23:59:59          51       O_243
#
#      FixedCost  VariableCost
# 445        200           1.5
# 446        200           1.5
# 447        200           1.5
# 448        200           1.5
# 449        200           1.5
# ('O_243', 25000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 460    462   25000        00:00:00      23:59:59          55       O_243
# 461    463   25000        00:00:00      23:59:59          55       O_243
# 462    464   25000        00:00:00      23:59:59          55       O_243
# 463    465   25000        00:00:00      23:59:59          55       O_243
# 464    466   25000        00:00:00      23:59:59          55       O_243
#
#      FixedCost  VariableCost
# 460        250           1.8
# 461        250           1.8
# 462        250           1.8
# 463        250           1.8
# 464        250           1.8
# ('O_284', 5000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 475    477    5000        00:00:00      23:59:59          27       O_284
# 476    478    5000        00:00:00      23:59:59          27       O_284
# 477    479    5000        00:00:00      23:59:59          27       O_284
# 478    480    5000        00:00:00      23:59:59          27       O_284
# 479    481    5000        00:00:00      23:59:59          27       O_284
#
#      FixedCost  VariableCost
# 475         80           0.8
# 476         80           0.8
# 477         80           0.8
# 478         80           0.8
# 479         80           0.8
# ('O_284', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 480    482    8000        00:00:00      23:59:59          33       O_284
# 481    483    8000        00:00:00      23:59:59          33       O_284
# 482    484    8000        00:00:00      23:59:59          33       O_284
# 483    485    8000        00:00:00      23:59:59          33       O_284
# 484    486    8000        00:00:00      23:59:59          33       O_284
#
#      FixedCost  VariableCost
# 480        110           1.0
# 481        110           1.0
# 482        110           1.0
# 483        110           1.0
# 484        110           1.0
# ('O_284', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 485    487   11000        00:00:00      23:59:59          42       O_284
# 486    488   11000        00:00:00      23:59:59          42       O_284
# 487    489   11000        00:00:00      23:59:59          42       O_284
# 488    490   11000        00:00:00      23:59:59          42       O_284
# 489    491   11000        00:00:00      23:59:59          42       O_284
#
#      FixedCost  VariableCost
# 485        150           1.2
# 486        150           1.2
# 487        150           1.2
# 488        150           1.2
# 489        150           1.2
# ('O_284', 18000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 490    492   18000        00:00:00      23:59:59          51       O_284
# 491    493   18000        00:00:00      23:59:59          51       O_284
# 492    494   18000        00:00:00      23:59:59          51       O_284
# 493    495   18000        00:00:00      23:59:59          51       O_284
# 494    496   18000        00:00:00      23:59:59          51       O_284
#
#      FixedCost  VariableCost
# 490        200           1.5
# 491        200           1.5
# 492        200           1.5
# 493        200           1.5
# 494        200           1.5
# ('O_284', 25000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 495    497   25000        00:00:00      23:59:59          55       O_284
# 496    498   25000        00:00:00      23:59:59          55       O_284
# 497    499   25000        00:00:00      23:59:59          55       O_284
# 498    500   25000        00:00:00      23:59:59          55       O_284
# 499    501   25000        00:00:00      23:59:59          55       O_284
#
#      FixedCost  VariableCost
# 495        250           1.8
# 496        250           1.8
# 497        250           1.8
# 498        250           1.8
# 499        250           1.8
# ('O_292', 5000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 500    502    5000        00:00:00      23:59:59          27       O_292
# 501    503    5000        00:00:00      23:59:59          27       O_292
# 502    504    5000        00:00:00      23:59:59          27       O_292
# 503    505    5000        00:00:00      23:59:59          27       O_292
# 504    506    5000        00:00:00      23:59:59          27       O_292
#
#      FixedCost  VariableCost
# 500         80           0.8
# 501         80           0.8
# 502         80           0.8
# 503         80           0.8
# 504         80           0.8
# ('O_292', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 505    507    8000        00:00:00      23:59:59          33       O_292
# 506    508    8000        00:00:00      23:59:59          33       O_292
# 507    509    8000        00:00:00      23:59:59          33       O_292
# 508    510    8000        00:00:00      23:59:59          33       O_292
# 509    511    8000        00:00:00      23:59:59          33       O_292
#
#      FixedCost  VariableCost
# 505        110           1.0
# 506        110           1.0
# 507        110           1.0
# 508        110           1.0
# 509        110           1.0
# ('O_292', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 510    512   11000        00:00:00      23:59:59          42       O_292
# 511    513   11000        00:00:00      23:59:59          42       O_292
# 512    514   11000        00:00:00      23:59:59          42       O_292
# 513    515   11000        00:00:00      23:59:59          42       O_292
# 514    516   11000        00:00:00      23:59:59          42       O_292
#
#      FixedCost  VariableCost
# 510        150           1.2
# 511        150           1.2
# 512        150           1.2
# 513        150           1.2
# 514        150           1.2
# ('O_292', 18000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 515    517   18000        00:00:00      23:59:59          51       O_292
# 516    518   18000        00:00:00      23:59:59          51       O_292
# 517    519   18000        00:00:00      23:59:59          51       O_292
# 518    520   18000        00:00:00      23:59:59          51       O_292
# 519    521   18000        00:00:00      23:59:59          51       O_292
#
#      FixedCost  VariableCost
# 515        200           1.5
# 516        200           1.5
# 517        200           1.5
# 518        200           1.5
# 519        200           1.5
# ('O_292', 25000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 520    522   25000        00:00:00      23:59:59          55       O_292
# 521    523   25000        00:00:00      23:59:59          55       O_292
# 522    524   25000        00:00:00      23:59:59          55       O_292
# 523    525   25000        00:00:00      23:59:59          55       O_292
# 524    526   25000        00:00:00      23:59:59          55       O_292
#
#      FixedCost  VariableCost
# 520        250           1.8
# 521        250           1.8
# 522        250           1.8
# 523        250           1.8
# 524        250           1.8
# ('O_323', 5000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 525    527    5000        00:00:00      23:59:59          27       O_323
# 526    528    5000        00:00:00      23:59:59          27       O_323
# 527    529    5000        00:00:00      23:59:59          27       O_323
# 528    530    5000        00:00:00      23:59:59          27       O_323
# 529    531    5000        00:00:00      23:59:59          27       O_323
#
#      FixedCost  VariableCost
# 525         80           0.8
# 526         80           0.8
# 527         80           0.8
# 528         80           0.8
# 529         80           0.8
# ('O_323', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 530    532    8000        00:00:00      23:59:59          33       O_323
# 531    533    8000        00:00:00      23:59:59          33       O_323
# 532    534    8000        00:00:00      23:59:59          33       O_323
# 533    535    8000        00:00:00      23:59:59          33       O_323
# 534    536    8000        00:00:00      23:59:59          33       O_323
#
#      FixedCost  VariableCost
# 530        110           1.0
# 531        110           1.0
# 532        110           1.0
# 533        110           1.0
# 534        110           1.0
# ('O_323', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 535    537   11000        00:00:00      23:59:59          42       O_323
# 536    538   11000        00:00:00      23:59:59          42       O_323
# 537    539   11000        00:00:00      23:59:59          42       O_323
# 538    540   11000        00:00:00      23:59:59          42       O_323
# 539    541   11000        00:00:00      23:59:59          42       O_323
#
#      FixedCost  VariableCost
# 535        150           1.2
# 536        150           1.2
# 537        150           1.2
# 538        150           1.2
# 539        150           1.2
# ('O_323', 18000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 540    542   18000        00:00:00      23:59:59          51       O_323
# 541    543   18000        00:00:00      23:59:59          51       O_323
# 542    544   18000        00:00:00      23:59:59          51       O_323
# 543    545   18000        00:00:00      23:59:59          51       O_323
# 544    546   18000        00:00:00      23:59:59          51       O_323
#
#      FixedCost  VariableCost
# 540        200           1.5
# 541        200           1.5
# 542        200           1.5
# 543        200           1.5
# 544        200           1.5
# ('O_323', 25000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 545    547   25000        00:00:00      23:59:59          55       O_323
# 546    548   25000        00:00:00      23:59:59          55       O_323
# 547    549   25000        00:00:00      23:59:59          55       O_323
# 548    550   25000        00:00:00      23:59:59          55       O_323
# 549    551   25000        00:00:00      23:59:59          55       O_323
#
#      FixedCost  VariableCost
# 545        250           1.8
# 546        250           1.8
# 547        250           1.8
# 548        250           1.8
# 549        250           1.8
# ('O_326', 5000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 550    552    5000        00:00:00      23:59:59          27       O_326
# 551    553    5000        00:00:00      23:59:59          27       O_326
# 552    554    5000        00:00:00      23:59:59          27       O_326
# 553    555    5000        00:00:00      23:59:59          27       O_326
# 554    556    5000        00:00:00      23:59:59          27       O_326
#
#      FixedCost  VariableCost
# 550         80           0.8
# 551         80           0.8
# 552         80           0.8
# 553         80           0.8
# 554         80           0.8
# ('O_326', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 565    567    8000        00:00:00      23:59:59          33       O_326
# 566    568    8000        00:00:00      23:59:59          33       O_326
# 567    569    8000        00:00:00      23:59:59          33       O_326
# 568    570    8000        00:00:00      23:59:59          33       O_326
# 569    571    8000        00:00:00      23:59:59          33       O_326
#
#      FixedCost  VariableCost
# 565        110           1.0
# 566        110           1.0
# 567        110           1.0
# 568        110           1.0
# 569        110           1.0
# ('O_326', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 580    582   11000        00:00:00      23:59:59          42       O_326
# 581    583   11000        00:00:00      23:59:59          42       O_326
# 582    584   11000        00:00:00      23:59:59          42       O_326
# 583    585   11000        00:00:00      23:59:59          42       O_326
# 584    586   11000        00:00:00      23:59:59          42       O_326
#
#      FixedCost  VariableCost
# 580        150           1.2
# 581        150           1.2
# 582        150           1.2
# 583        150           1.2
# 584        150           1.2
# ('O_326', 18000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 595    597   18000        00:00:00      23:59:59          51       O_326
# 596    598   18000        00:00:00      23:59:59          51       O_326
# 597    599   18000        00:00:00      23:59:59          51       O_326
# 598    600   18000        00:00:00      23:59:59          51       O_326
# 599    601   18000        00:00:00      23:59:59          51       O_326
#
#      FixedCost  VariableCost
# 595        200           1.5
# 596        200           1.5
# 597        200           1.5
# 598        200           1.5
# 599        200           1.5
# ('O_326', 25000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 610    612   25000        00:00:00      23:59:59          55       O_326
# 611    613   25000        00:00:00      23:59:59          55       O_326
# 612    614   25000        00:00:00      23:59:59          55       O_326
# 613    615   25000        00:00:00      23:59:59          55       O_326
# 614    616   25000        00:00:00      23:59:59          55       O_326
#
#      FixedCost  VariableCost
# 610        250           1.8
# 611        250           1.8
# 612        250           1.8
# 613        250           1.8
# 614        250           1.8
# ('O_34', 5000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 100    102    5000        00:00:00      23:59:59          27        O_34
# 101    103    5000        00:00:00      23:59:59          27        O_34
# 102    104    5000        00:00:00      23:59:59          27        O_34
# 103    105    5000        00:00:00      23:59:59          27        O_34
# 104    106    5000        00:00:00      23:59:59          27        O_34
#
#      FixedCost  VariableCost
# 100         80           0.8
# 101         80           0.8
# 102         80           0.8
# 103         80           0.8
# 104         80           0.8
# ('O_34', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 105    107    8000        00:00:00      23:59:59          33        O_34
# 106    108    8000        00:00:00      23:59:59          33        O_34
# 107    109    8000        00:00:00      23:59:59          33        O_34
# 108    110    8000        00:00:00      23:59:59          33        O_34
# 109    111    8000        00:00:00      23:59:59          33        O_34
#
#      FixedCost  VariableCost
# 105        110           1.0
# 106        110           1.0
# 107        110           1.0
# 108        110           1.0
# 109        110           1.0
# ('O_34', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 110    112   11000        00:00:00      23:59:59          42        O_34
# 111    113   11000        00:00:00      23:59:59          42        O_34
# 112    114   11000        00:00:00      23:59:59          42        O_34
# 113    115   11000        00:00:00      23:59:59          42        O_34
# 114    116   11000        00:00:00      23:59:59          42        O_34
#
#      FixedCost  VariableCost
# 110        150           1.2
# 111        150           1.2
# 112        150           1.2
# 113        150           1.2
# 114        150           1.2
# ('O_34', 18000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 115    117   18000        00:00:00      23:59:59          51        O_34
# 116    118   18000        00:00:00      23:59:59          51        O_34
# 117    119   18000        00:00:00      23:59:59          51        O_34
# 118    120   18000        00:00:00      23:59:59          51        O_34
# 119    121   18000        00:00:00      23:59:59          51        O_34
#
#      FixedCost  VariableCost
# 115        200           1.5
# 116        200           1.5
# 117        200           1.5
# 118        200           1.5
# 119        200           1.5
# ('O_34', 25000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 120    122   25000        00:00:00      23:59:59          55        O_34
# 121    123   25000        00:00:00      23:59:59          55        O_34
# 122    124   25000        00:00:00      23:59:59          55        O_34
# 123    125   25000        00:00:00      23:59:59          55        O_34
# 124    126   25000        00:00:00      23:59:59          55        O_34
#
#      FixedCost  VariableCost
# 120        250           1.8
# 121        250           1.8
# 122        250           1.8
# 123        250           1.8
# 124        250           1.8
# ('O_349', 5000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 625    627    5000        00:00:00      23:59:59          27       O_349
# 626    628    5000        00:00:00      23:59:59          27       O_349
# 627    629    5000        00:00:00      23:59:59          27       O_349
# 628    630    5000        00:00:00      23:59:59          27       O_349
# 629    631    5000        00:00:00      23:59:59          27       O_349
#
#      FixedCost  VariableCost
# 625         80           0.8
# 626         80           0.8
# 627         80           0.8
# 628         80           0.8
# 629         80           0.8
# ('O_349', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 630    632    8000        00:00:00      23:59:59          33       O_349
# 631    633    8000        00:00:00      23:59:59          33       O_349
# 632    634    8000        00:00:00      23:59:59          33       O_349
# 633    635    8000        00:00:00      23:59:59          33       O_349
# 634    636    8000        00:00:00      23:59:59          33       O_349
#
#      FixedCost  VariableCost
# 630        110           1.0
# 631        110           1.0
# 632        110           1.0
# 633        110           1.0
# 634        110           1.0
# ('O_349', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 635    637   11000        00:00:00      23:59:59          42       O_349
# 636    638   11000        00:00:00      23:59:59          42       O_349
# 637    639   11000        00:00:00      23:59:59          42       O_349
# 638    640   11000        00:00:00      23:59:59          42       O_349
# 639    641   11000        00:00:00      23:59:59          42       O_349
#
#      FixedCost  VariableCost
# 635        150           1.2
# 636        150           1.2
# 637        150           1.2
# 638        150           1.2
# 639        150           1.2
# ('O_349', 18000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 640    642   18000        00:00:00      23:59:59          51       O_349
# 641    643   18000        00:00:00      23:59:59          51       O_349
# 642    644   18000        00:00:00      23:59:59          51       O_349
# 643    645   18000        00:00:00      23:59:59          51       O_349
# 644    646   18000        00:00:00      23:59:59          51       O_349
#
#      FixedCost  VariableCost
# 640        200           1.5
# 641        200           1.5
# 642        200           1.5
# 643        200           1.5
# 644        200           1.5
# ('O_349', 25000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 645    647   25000        00:00:00      23:59:59          55       O_349
# 646    648   25000        00:00:00      23:59:59          55       O_349
# 647    649   25000        00:00:00      23:59:59          55       O_349
# 648    650   25000        00:00:00      23:59:59          55       O_349
# 649    651   25000        00:00:00      23:59:59          55       O_349
#
#      FixedCost  VariableCost
# 645        250           1.8
# 646        250           1.8
# 647        250           1.8
# 648        250           1.8
# 649        250           1.8
# ('O_352', 5000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 650    652    5000        00:00:00      23:59:59          27       O_352
# 651    653    5000        00:00:00      23:59:59          27       O_352
# 652    654    5000        00:00:00      23:59:59          27       O_352
# 653    655    5000        00:00:00      23:59:59          27       O_352
# 654    656    5000        00:00:00      23:59:59          27       O_352
#
#      FixedCost  VariableCost
# 650         80           0.8
# 651         80           0.8
# 652         80           0.8
# 653         80           0.8
# 654         80           0.8
# ('O_352', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 655    657    8000        00:00:00      23:59:59          33       O_352
# 656    658    8000        00:00:00      23:59:59          33       O_352
# 657    659    8000        00:00:00      23:59:59          33       O_352
# 658    660    8000        00:00:00      23:59:59          33       O_352
# 659    661    8000        00:00:00      23:59:59          33       O_352
#
#      FixedCost  VariableCost
# 655        110           1.0
# 656        110           1.0
# 657        110           1.0
# 658        110           1.0
# 659        110           1.0
# ('O_352', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 660    662   11000        00:00:00      23:59:59          42       O_352
# 661    663   11000        00:00:00      23:59:59          42       O_352
# 662    664   11000        00:00:00      23:59:59          42       O_352
# 663    665   11000        00:00:00      23:59:59          42       O_352
# 664    666   11000        00:00:00      23:59:59          42       O_352
#
#      FixedCost  VariableCost
# 660        150           1.2
# 661        150           1.2
# 662        150           1.2
# 663        150           1.2
# 664        150           1.2
# ('O_352', 18000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 665    667   18000        00:00:00      23:59:59          51       O_352
# 666    668   18000        00:00:00      23:59:59          51       O_352
# 667    669   18000        00:00:00      23:59:59          51       O_352
# 668    670   18000        00:00:00      23:59:59          51       O_352
# 669    671   18000        00:00:00      23:59:59          51       O_352
#
#      FixedCost  VariableCost
# 665        200           1.5
# 666        200           1.5
# 667        200           1.5
# 668        200           1.5
# 669        200           1.5
# ('O_352', 25000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 670    672   25000        00:00:00      23:59:59          55       O_352
# 671    673   25000        00:00:00      23:59:59          55       O_352
# 672    674   25000        00:00:00      23:59:59          55       O_352
# 673    675   25000        00:00:00      23:59:59          55       O_352
# 674    676   25000        00:00:00      23:59:59          55       O_352
#
#      FixedCost  VariableCost
# 670        250           1.8
# 671        250           1.8
# 672        250           1.8
# 673        250           1.8
# 674        250           1.8
# ('O_376', 5000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 675    677    5000        00:00:00      23:59:59          27       O_376
# 676    678    5000        00:00:00      23:59:59          27       O_376
# 677    679    5000        00:00:00      23:59:59          27       O_376
# 678    680    5000        00:00:00      23:59:59          27       O_376
# 679    681    5000        00:00:00      23:59:59          27       O_376
#
#      FixedCost  VariableCost
# 675         80           0.8
# 676         80           0.8
# 677         80           0.8
# 678         80           0.8
# 679         80           0.8
# ('O_376', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 680    682    8000        00:00:00      23:59:59          33       O_376
# 681    683    8000        00:00:00      23:59:59          33       O_376
# 682    684    8000        00:00:00      23:59:59          33       O_376
# 683    685    8000        00:00:00      23:59:59          33       O_376
# 684    686    8000        00:00:00      23:59:59          33       O_376
#
#      FixedCost  VariableCost
# 680        110           1.0
# 681        110           1.0
# 682        110           1.0
# 683        110           1.0
# 684        110           1.0
# ('O_376', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 685    687   11000        00:00:00      23:59:59          42       O_376
# 686    688   11000        00:00:00      23:59:59          42       O_376
# 687    689   11000        00:00:00      23:59:59          42       O_376
# 688    690   11000        00:00:00      23:59:59          42       O_376
# 689    691   11000        00:00:00      23:59:59          42       O_376
#
#      FixedCost  VariableCost
# 685        150           1.2
# 686        150           1.2
# 687        150           1.2
# 688        150           1.2
# 689        150           1.2
# ('O_376', 18000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 690    692   18000        00:00:00      23:59:59          51       O_376
# 691    693   18000        00:00:00      23:59:59          51       O_376
# 692    694   18000        00:00:00      23:59:59          51       O_376
# 693    695   18000        00:00:00      23:59:59          51       O_376
# 694    696   18000        00:00:00      23:59:59          51       O_376
#
#      FixedCost  VariableCost
# 690        200           1.5
# 691        200           1.5
# 692        200           1.5
# 693        200           1.5
# 694        200           1.5
# ('O_376', 25000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 695    697   25000        00:00:00      23:59:59          55       O_376
# 696    698   25000        00:00:00      23:59:59          55       O_376
# 697    699   25000        00:00:00      23:59:59          55       O_376
# 698    700   25000        00:00:00      23:59:59          55       O_376
# 699    701   25000        00:00:00      23:59:59          55       O_376
#
#      FixedCost  VariableCost
# 695        250           1.8
# 696        250           1.8
# 697        250           1.8
# 698        250           1.8
# 699        250           1.8
# ('O_430', 5000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 700    702    5000        00:00:00      23:59:59          27       O_430
# 701    703    5000        00:00:00      23:59:59          27       O_430
# 702    704    5000        00:00:00      23:59:59          27       O_430
# 703    705    5000        00:00:00      23:59:59          27       O_430
# 704    706    5000        00:00:00      23:59:59          27       O_430
#
#      FixedCost  VariableCost
# 700         80           0.8
# 701         80           0.8
# 702         80           0.8
# 703         80           0.8
# 704         80           0.8
# ('O_430', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 705    707    8000        00:00:00      23:59:59          33       O_430
# 706    708    8000        00:00:00      23:59:59          33       O_430
# 707    709    8000        00:00:00      23:59:59          33       O_430
# 708    710    8000        00:00:00      23:59:59          33       O_430
# 709    711    8000        00:00:00      23:59:59          33       O_430
#
#      FixedCost  VariableCost
# 705        110           1.0
# 706        110           1.0
# 707        110           1.0
# 708        110           1.0
# 709        110           1.0
# ('O_430', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 710    712   11000        00:00:00      23:59:59          42       O_430
# 711    713   11000        00:00:00      23:59:59          42       O_430
# 712    714   11000        00:00:00      23:59:59          42       O_430
# 713    715   11000        00:00:00      23:59:59          42       O_430
# 714    716   11000        00:00:00      23:59:59          42       O_430
#
#      FixedCost  VariableCost
# 710        150           1.2
# 711        150           1.2
# 712        150           1.2
# 713        150           1.2
# 714        150           1.2
# ('O_430', 18000)
# ...
# 201         80           0.8
# 202         80           0.8
# 203         80           0.8
# 204         80           0.8
# ('O_70', 8000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 205    207    8000        00:00:00      23:59:59          33        O_70
# 206    208    8000        00:00:00      23:59:59          33        O_70
# 207    209    8000        00:00:00      23:59:59          33        O_70
# 208    210    8000        00:00:00      23:59:59          33        O_70
# 209    211    8000        00:00:00      23:59:59          33        O_70
#
#      FixedCost  VariableCost
# 205        110           1.0
# 206        110           1.0
# 207        110           1.0
# 208        110           1.0
# 209        110           1.0
# ('O_70', 11000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 210    212   11000        00:00:00      23:59:59          42        O_70
# 211    213   11000        00:00:00      23:59:59          42        O_70
# 212    214   11000        00:00:00      23:59:59          42        O_70
# 213    215   11000        00:00:00      23:59:59          42        O_70
# 214    216   11000        00:00:00      23:59:59          42        O_70
#
#      FixedCost  VariableCost
# 210        150           1.2
# 211        150           1.2
# 212        150           1.2
# 213        150           1.2
# 214        150           1.2
# ('O_70', 18000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 215    217   18000        00:00:00      23:59:59          51        O_70
# 216    218   18000        00:00:00      23:59:59          51        O_70
# 217    219   18000        00:00:00      23:59:59          51        O_70
# 218    220   18000        00:00:00      23:59:59          51        O_70
# 219    221   18000        00:00:00      23:59:59          51        O_70
#
#      FixedCost  VariableCost
# 215        200           1.5
# 216        200           1.5
# 217        200           1.5
# 218        200           1.5
# 219        200           1.5
# ('O_70', 25000)
#     VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 220    222   25000        00:00:00      23:59:59          55        O_70
# 221    223   25000        00:00:00      23:59:59          55        O_70
# 222    224   25000        00:00:00      23:59:59          55        O_70
# 223    225   25000        00:00:00      23:59:59          55        O_70
# 224    226   25000        00:00:00      23:59:59          55        O_70
#
#      FixedCost  VariableCost
# 220        250           1.8
# 221        250           1.8
# 222        250           1.8
# 223        250           1.8
# 224        250           1.8
# ('O_711', 5000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1050   1052    5000        00:00:00      23:59:59          27       O_711
# 1051   1053    5000        00:00:00      23:59:59          27       O_711
# 1052   1054    5000        00:00:00      23:59:59          27       O_711
# 1053   1055    5000        00:00:00      23:59:59          27       O_711
# 1054   1056    5000        00:00:00      23:59:59          27       O_711
#
#       FixedCost  VariableCost
# 1050         80           0.8
# 1051         80           0.8
# 1052         80           0.8
# 1053         80           0.8
# 1054         80           0.8
# ('O_711', 8000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1055   1057    8000        00:00:00      23:59:59          33       O_711
# 1056   1058    8000        00:00:00      23:59:59          33       O_711
# 1057   1059    8000        00:00:00      23:59:59          33       O_711
# 1058   1060    8000        00:00:00      23:59:59          33       O_711
# 1059   1061    8000        00:00:00      23:59:59          33       O_711
#
#       FixedCost  VariableCost
# 1055        110           1.0
# 1056        110           1.0
# 1057        110           1.0
# 1058        110           1.0
# 1059        110           1.0
# ('O_711', 11000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1060   1062   11000        00:00:00      23:59:59          42       O_711
# 1061   1063   11000        00:00:00      23:59:59          42       O_711
# 1062   1064   11000        00:00:00      23:59:59          42       O_711
# 1063   1065   11000        00:00:00      23:59:59          42       O_711
# 1064   1066   11000        00:00:00      23:59:59          42       O_711
#
#       FixedCost  VariableCost
# 1060        150           1.2
# 1061        150           1.2
# 1062        150           1.2
# 1063        150           1.2
# 1064        150           1.2
# ('O_711', 18000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1065   1067   18000        00:00:00      23:59:59          51       O_711
# 1066   1068   18000        00:00:00      23:59:59          51       O_711
# 1067   1069   18000        00:00:00      23:59:59          51       O_711
# 1068   1070   18000        00:00:00      23:59:59          51       O_711
# 1069   1071   18000        00:00:00      23:59:59          51       O_711
#
#       FixedCost  VariableCost
# 1065        200           1.5
# 1066        200           1.5
# 1067        200           1.5
# 1068        200           1.5
# 1069        200           1.5
# ('O_711', 25000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1070   1072   25000        00:00:00      23:59:59          55       O_711
# 1071   1073   25000        00:00:00      23:59:59          55       O_711
# 1072   1074   25000        00:00:00      23:59:59          55       O_711
# 1073   1075   25000        00:00:00      23:59:59          55       O_711
# 1074   1076   25000        00:00:00      23:59:59          55       O_711
#
#       FixedCost  VariableCost
# 1070        250           1.8
# 1071        250           1.8
# 1072        250           1.8
# 1073        250           1.8
# 1074        250           1.8
# ('O_756', 5000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1075   1077    5000        00:00:00      23:59:59          27       O_756
# 1076   1078    5000        00:00:00      23:59:59          27       O_756
# 1077   1079    5000        00:00:00      23:59:59          27       O_756
# 1078   1080    5000        00:00:00      23:59:59          27       O_756
# 1079   1081    5000        00:00:00      23:59:59          27       O_756
#
#       FixedCost  VariableCost
# 1075         80           0.8
# 1076         80           0.8
# 1077         80           0.8
# 1078         80           0.8
# 1079         80           0.8
# ('O_756', 8000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1080   1082    8000        00:00:00      23:59:59          33       O_756
# 1081   1083    8000        00:00:00      23:59:59          33       O_756
# 1082   1084    8000        00:00:00      23:59:59          33       O_756
# 1083   1085    8000        00:00:00      23:59:59          33       O_756
# 1084   1086    8000        00:00:00      23:59:59          33       O_756
#
#       FixedCost  VariableCost
# 1080        110           1.0
# 1081        110           1.0
# 1082        110           1.0
# 1083        110           1.0
# 1084        110           1.0
# ('O_756', 11000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1085   1087   11000        00:00:00      23:59:59          42       O_756
# 1086   1088   11000        00:00:00      23:59:59          42       O_756
# 1087   1089   11000        00:00:00      23:59:59          42       O_756
# 1088   1090   11000        00:00:00      23:59:59          42       O_756
# 1089   1091   11000        00:00:00      23:59:59          42       O_756
#
#       FixedCost  VariableCost
# 1085        150           1.2
# 1086        150           1.2
# 1087        150           1.2
# 1088        150           1.2
# 1089        150           1.2
# ('O_756', 18000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1090   1092   18000        00:00:00      23:59:59          51       O_756
# 1091   1093   18000        00:00:00      23:59:59          51       O_756
# 1092   1094   18000        00:00:00      23:59:59          51       O_756
# 1093   1095   18000        00:00:00      23:59:59          51       O_756
# 1094   1096   18000        00:00:00      23:59:59          51       O_756
#
#       FixedCost  VariableCost
# 1090        200           1.5
# 1091        200           1.5
# 1092        200           1.5
# 1093        200           1.5
# 1094        200           1.5
# ('O_756', 25000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1095   1097   25000        00:00:00      23:59:59          55       O_756
# 1096   1098   25000        00:00:00      23:59:59          55       O_756
# 1097   1099   25000        00:00:00      23:59:59          55       O_756
# 1098   1100   25000        00:00:00      23:59:59          55       O_756
# 1099   1101   25000        00:00:00      23:59:59          55       O_756
#
#       FixedCost  VariableCost
# 1095        250           1.8
# 1096        250           1.8
# 1097        250           1.8
# 1098        250           1.8
# 1099        250           1.8
# ('O_770', 5000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1100   1102    5000        00:00:00      23:59:59          27       O_770
# 1101   1103    5000        00:00:00      23:59:59          27       O_770
# 1102   1104    5000        00:00:00      23:59:59          27       O_770
# 1103   1105    5000        00:00:00      23:59:59          27       O_770
# 1104   1106    5000        00:00:00      23:59:59          27       O_770
#
#       FixedCost  VariableCost
# 1100         80           0.8
# 1101         80           0.8
# 1102         80           0.8
# 1103         80           0.8
# 1104         80           0.8
# ('O_770', 8000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1105   1107    8000        00:00:00      23:59:59          33       O_770
# 1106   1108    8000        00:00:00      23:59:59          33       O_770
# 1107   1109    8000        00:00:00      23:59:59          33       O_770
# 1108   1110    8000        00:00:00      23:59:59          33       O_770
# 1109   1111    8000        00:00:00      23:59:59          33       O_770
#
#       FixedCost  VariableCost
# 1105        110           1.0
# 1106        110           1.0
# 1107        110           1.0
# 1108        110           1.0
# 1109        110           1.0
# ('O_770', 11000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1110   1112   11000        00:00:00      23:59:59          42       O_770
# 1111   1113   11000        00:00:00      23:59:59          42       O_770
# 1112   1114   11000        00:00:00      23:59:59          42       O_770
# 1113   1115   11000        00:00:00      23:59:59          42       O_770
# 1114   1116   11000        00:00:00      23:59:59          42       O_770
#
#       FixedCost  VariableCost
# 1110        150           1.2
# 1111        150           1.2
# 1112        150           1.2
# 1113        150           1.2
# 1114        150           1.2
# ('O_770', 18000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1115   1117   18000        00:00:00      23:59:59          51       O_770
# 1116   1118   18000        00:00:00      23:59:59          51       O_770
# 1117   1119   18000        00:00:00      23:59:59          51       O_770
# 1118   1120   18000        00:00:00      23:59:59          51       O_770
# 1119   1121   18000        00:00:00      23:59:59          51       O_770
#
#       FixedCost  VariableCost
# 1115        200           1.5
# 1116        200           1.5
# 1117        200           1.5
# 1118        200           1.5
# 1119        200           1.5
# ('O_770', 25000)
#      VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 1120   1122   25000        00:00:00      23:59:59          55       O_770
# 1121   1123   25000        00:00:00      23:59:59          55       O_770
# 1122   1124   25000        00:00:00      23:59:59          55       O_770
# 1123   1125   25000        00:00:00      23:59:59          55       O_770
# 1124   1126   25000        00:00:00      23:59:59          55       O_770
#
#       FixedCost  VariableCost
# 1120        250           1.8
# 1121        250           1.8
# 1122        250           1.8
# 1123        250           1.8
# 1124        250           1.8
# ('O_9', 5000)
#   VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 0      2    5000        00:00:00      23:59:59          27         O_9
# 1      3    5000        00:00:00      23:59:59          27         O_9
# 2      4    5000        00:00:00      23:59:59          27         O_9
# 3      5    5000        00:00:00      23:59:59          27         O_9
# 4      6    5000        00:00:00      23:59:59          27         O_9
#
#    FixedCost  VariableCost
# 0         80           0.8
# 1         80           0.8
# 2         80           0.8
# 3         80           0.8
# 4         80           0.8
# ('O_9', 8000)
#    VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 10     12    8000        00:00:00      23:59:59          33         O_9
# 11     13    8000        00:00:00      23:59:59          33         O_9
# 12     14    8000        00:00:00      23:59:59          33         O_9
# 13     15    8000        00:00:00      23:59:59          33         O_9
# 14     16    8000        00:00:00      23:59:59          33         O_9
#
#     FixedCost  VariableCost
# 10        110           1.0
# 11        110           1.0
# 12        110           1.0
# 13        110           1.0
# 14        110           1.0
# ('O_9', 11000)
#    VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 20     22   11000        00:00:00      23:59:59          42         O_9
# 21     23   11000        00:00:00      23:59:59          42         O_9
# 22     24   11000        00:00:00      23:59:59          42         O_9
# 23     25   11000        00:00:00      23:59:59          42         O_9
# 24     26   11000        00:00:00      23:59:59          42         O_9
#
#     FixedCost  VariableCost
# 20        150           1.2
# 21        150           1.2
# 22        150           1.2
# 23        150           1.2
# 24        150           1.2
# ('O_9', 18000)
#    VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 30     32   18000        00:00:00      23:59:59          51         O_9
# 31     33   18000        00:00:00      23:59:59          51         O_9
# 32     34   18000        00:00:00      23:59:59          51         O_9
# 33     35   18000        00:00:00      23:59:59          51         O_9
# 34     36   18000        00:00:00      23:59:59          51         O_9
#
#     FixedCost  VariableCost
# 30        200           1.5
# 31        200           1.5
# 32        200           1.5
# 33        200           1.5
# 34        200           1.5
# ('O_9', 25000)
#    VehNum  VehTon BusinessStartTM BusinessEndTM  MaxCapaCBM StartCenter  \
# 40     42   25000        00:00:00      23:59:59          55         O_9
# 41     43   25000        00:00:00      23:59:59          55         O_9
# 42     44   25000        00:00:00      23:59:59          55         O_9
# 43     45   25000        00:00:00      23:59:59          55         O_9
# 44     46   25000        00:00:00      23:59:59          55         O_9
#
#     FixedCost  VariableCost
# 40        250           1.8
# 41        250           1.8
# 42        250           1.8
# 43        250           1.8
# 44        250           1.8

# %% [markdown]
# ##OD_Table

# %%
od_table.isnull().sum()
# Out:
# origin           0
# destination      0
# length(meter)    0
# time(min)        0
# dtype: int64

# %%
od_table.shape
# Out:
# (2130444, 4)

# %%
od_table.dtypes
# Out:
# origin            object
# destination       object
# length(meter)    float64
# time(min)        float64
# dtype: object

# %%
od_table.head()
# Out:
#   origin destination  length(meter)  time(min)
# 0   D_69        D_69       0.000000   0.000000
# 1   D_69      D_1916      10.570963   6.912456
# 2   D_69       D_562      13.150193   8.981368
# 3   D_69        D_12      18.617520  14.798563
# 4   D_69      D_1587      27.680115  20.461350

# %% [markdown]
# ##데이터 전처리?

# %%
##시작 터미널에서의 차량 개수
veh_group_start_center = veh_table[['StartCenter','VehTon']].groupby(['StartCenter','VehTon'])
veh_group_start_center = veh_group_start_center.size().reset_index(name='counts')
pivot_veh_group_start_center = pd.pivot_table(veh_group_start_center, index='StartCenter', values='counts', columns=['VehTon'])
pivot_veh_group_start_center.columns.name = None
pivot_veh_group_start_center.columns = ['VehTon_5000','VehTon_8000','VehTon_11000', 'VehTon_18000', 'VehTon_25000']

# %%
## 터미널 별 특성 나타내기(톤별 차량 개수, 주문량)
terminal_variable_df = pd.merge(pivot_veh_group_start_center, terminal_ot, left_on = 'StartCenter', right_index = True,  how = 'outer')
terminal_variable_df
# Out:
#              VehTon_5000  VehTon_8000  VehTon_11000  VehTon_18000  \
# StartCenter
# O_11                  10           10            10            10
# O_123                  5            5             5             5
# O_144                 15           15            15            15
# O_174                  5            5             5             5
# O_179                 10           10            10            10
# O_243                 15           15            15            15
# O_284                  5            5             5             5
# O_292                  5            5             5             5
# O_323                  5            5             5             5
# O_326                 15           15            15            15
# O_34                   5            5             5             5
# O_349                  5            5             5             5
# O_352                  5            5             5             5
# O_376                  5            5             5             5
# O_430                  5            5             5             5
# O_448                 10           10            10            10
# O_45                   5            5             5             5
# O_466                  5            5             5             5
# O_50                   5            5             5             5
# O_553                  5            5             5             5
# O_578                  5            5             5             5
# O_580                  5            5             5             5
# O_591                  5            5             5             5
# O_603                  5            5             5             5
# O_62                   5            5             5             5
# O_629                  5            5             5             5
# O_673                 15           15            15            15
# O_685                  5            5             5             5
# O_70                   5            5             5             5
# O_711                  5            5             5             5
# O_756                  5            5             5             5
# O_770                  5            5             5             5
# O_9                   10           10            10            10
#
#              VehTon_25000  OrderCount
# StartCenter
# O_11                   10         843
# O_123                   5          56
# O_144                  15        2171
# O_174                   5         184
# O_179                  10         871
# O_243                  15        1002
# O_284                   5          35
# O_292                   5          15
# O_323                   5         345
# O_326                  15        4527
# O_34                    5          40
# O_349                   5         125
# O_352                   5         177
# O_376                   5         335
# O_430                   5          97
# O_448                  10         579
# O_45                    5          48
# O_466                   5          45
# O_50                    5         347
# O_553                   5          17
# O_578                   5          88
# O_580                   5          67
# O_591                   5          95
# O_603                   5         375
# O_62                    5         408
# O_629                   5         237
# O_673                  15        1604
# O_685                   5          39
# O_70                    5          28
# O_711                   5          88
# O_756                   5          12
# O_770                   5          13
# O_9                    10         704
